# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
happiness_2015 = (r"C:\Users\Hollow\Desktop\ETL_Project\RESOURCES\2015.csv")
happiness_df = pd.read_csv(happiness_2015)
happiness_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
ger_df = pd.read_csv("RESOURCES\gross_enrollment_ratio.csv")
ger_df.head()
# Out:
#            Country Name Country Code  \
# 0           Afghanistan          ABW
# 1                Angola          AFG
# 2               Albania          AGO
# 3               Andorra          ALB
# 4  Netherlands Antilles          AND
#
#                                       Indicator Name Indicator Code       2015
# 0  Gross enrolment ratio, primary and secondary, ...    UIS.GER.123        NaN
# 1  Gross enrolment ratio, primary and secondary, ...    UIS.GER.123   79.59898
# 2  Gross enrolment ratio, primary and secondary, ...    UIS.GER.123        NaN
# 3  Gross enrolment ratio, primary and secondary, ...    UIS.GER.123  100.28765
# 4  Gross enrolment ratio, primary and secondary, ...    UIS.GER.123        NaN

# %%
#happiness DataFrame cleaning
happiness_df.drop(columns=['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'], axis=1, inplace=True)
happiness_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error
# 0         0.03411
# 1         0.04884
# 2         0.03328
# 3         0.03880
# 4         0.03553

# %%
uls_df = pd.read_csv("RESOURCES\API_UIS.SLE.123_DS12_EN_csv_v2_1781678.csv")
uls_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name Indicator Code      2015
# 0  School life expectancy, primary and secondary,...    UIS.SLE.123       NaN
# 1  School life expectancy, primary and secondary,...    UIS.SLE.123   9.35507
# 2  School life expectancy, primary and secondary,...    UIS.SLE.123       NaN
# 3  School life expectancy, primary and secondary,...    UIS.SLE.123  11.97592
# 4  School life expectancy, primary and secondary,...    UIS.SLE.123       NaN
